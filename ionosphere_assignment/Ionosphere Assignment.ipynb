# %% [markdown]
# # Assignment: Ionosphere Data Problem
#
# ### Dataset Description:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this databse are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# ### Attribute Information:
#
# - All 34 are continuous
# - The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
#  <br><br>
#
# <table border="1"  cellpadding="6">
# 	<tbody>
#         <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Data Set Characteristics:&nbsp;&nbsp;</b></p></td>
# 		<td><p class="normal">Multivariate</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Instances:</b></p></td>
# 		<td><p class="normal">351</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Area:</b></p></td>
# 		<td><p class="normal">Physical</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#         <tr>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Attribute Characteristics:</b></p></td>
#             <td><p class="normal">Integer,Real</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Number of Attributes:</b></p></td>
#             <td><p class="normal">34</p></td>
#             <td bgcolor="#DDEEFF"><p class="normal"><b>Date Donated</b></p></td>
#             <td><p class="normal">N/A</p></td>
#         </tr>
#      </tbody>
#     </table>
# <table border="1" cellpadding="6">
#     <tbody>
#     <tr>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Associated Tasks:</b></p></td>
# 		<td><p class="normal">Classification</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Missing Values?</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 		<td bgcolor="#DDEEFF"><p class="normal"><b>Number of Web Hits:</b></p></td>
# 		<td><p class="normal">N/A</p></td>
# 	</tr>
#     </tbody>
#     </table>

# %% [markdown]
# ### WORKFLOW :
# - Load Data
# - Check Missing Values ( If Exist ; Fill each record with mean of its feature ) or any usless column.
# - Shuffle the data if needed.
# - Standardized the Input Variables. **Hint**: Centeralized the data
# - Split into 60 and 40 ratio.
# - Encode labels.
# - Model : 1 hidden layers including 16 unit.
# - Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
# - Train the Model with Epochs (100).
# - If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
# - Prediction should be > **92%**
# - Evaluation Step
# - Prediction

# %% [markdown]
# # Load Data:
# [Click Here to Download DataSet](https://github.com/ramsha275/ML_Datasets/blob/main/ionosphere_data.csv)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
data_set=pd.read_csv('ionosphere_dataset/ionosphere_data.csv')

# %%
data_set.head()
# Out:
#    feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0         1         0   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1         1         0   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2         1         0   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3         1         0   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4         1         0   1.00000  -0.02401   0.94140   0.06531   0.92106
#
#    feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# 0  -0.37708   1.00000    0.03760  ...   -0.51171    0.41078   -0.46168
# 1  -0.93597   1.00000   -0.04549  ...   -0.26569   -0.20468   -0.18401
# 2  -0.12062   0.88965    0.01198  ...   -0.40220    0.58984   -0.22145
# 3  -1.00000   0.00000    0.00000  ...    0.90695    0.51613    1.00000
# 4  -0.23255   0.77152   -0.16399  ...   -0.65158    0.13290   -0.53206
#
#    feature29  feature30  feature31  feature32  feature33  feature34  label
# 0    0.21266   -0.34090    0.42267   -0.54487    0.18641   -0.45300      g
# 1   -0.19040   -0.11593   -0.16626   -0.06288   -0.13738   -0.02447      b
# 2    0.43100   -0.17365    0.60436   -0.24180    0.56045   -0.38238      g
# 3    1.00000   -0.20099    0.25682    1.00000   -0.32382    1.00000      b
# 4    0.02431   -0.62197   -0.05707   -0.59573   -0.04608   -0.65697      g
#
# [5 rows x 35 columns]

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature2   351 non-null    int64
#  2   feature3   351 non-null    float64
#  3   feature4   351 non-null    float64
#  4   feature5   351 non-null    float64
#  5   feature6   351 non-null    float64
#  6   feature7   351 non-null    float64
#  7   feature8   351 non-null    float64
#  8   feature9   351 non-null    float64
#  9   feature10  351 non-null    float64
#  10  feature11  351 non-null    float64
#  11  feature12  351 non-null    float64
#  12  feature13  351 non-null    float64
#  13  feature14  351 non-null    float64
#  14  feature15  351 non-null    float64
#  15  feature16  351 non-null    float64
#  16  feature17  351 non-null    float64
#  17  feature18  351 non-null    float64
#  18  feature19  351 non-null    float64
#  19  feature20  351 non-null    float64
#  20  feature21  351 non-null    float64
#  21  feature22  351 non-null    float64
#  22  feature23  351 non-null    float64
#  23  feature24  351 non-null    float64
#  24  feature25  351 non-null    float64
#  25  feature26  351 non-null    float64
#  26  feature27  351 non-null    float64
#  27  feature28  351 non-null    float64
#  28  feature29  351 non-null    float64
#  29  feature30  351 non-null    float64
#  30  feature31  351 non-null    float64
#  31  feature32  351 non-null    float64
#  32  feature33  351 non-null    float64
#  33  feature34  351 non-null    float64
#  34  label      351 non-null    object
# dtypes: float64(32), int64(2), object(1)
# memory usage: 96.1+ KB

# %%
data_set.isnull().sum()
# Out:
# feature1     0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
data_set=data_set.sample(frac=1)

# %%
data_set.drop('feature2',
  axis='columns', inplace=True)

# %%
data_set.head()
# Out:
#      feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 103         1   0.95704  -0.12095   0.63318  -0.12690   0.96365  -0.18242
# 262         1   1.00000   0.09802   1.00000   0.25101   0.98390   0.33044
# 158         1   0.08696   0.00686   0.13959  -0.04119   0.10526  -0.08238
# 4           1   1.00000  -0.02401   0.94140   0.06531   0.92106  -0.23255
# 0           1   0.99539  -0.05889   0.85243   0.02306   0.83398  -0.37708
#
#      feature9  feature10  feature11  ...  feature26  feature27  feature28  \
# 103   0.97026    0.08460    0.92003  ...   -0.19233    0.88793   -0.31565
# 262   0.80365    0.53020    0.74977  ...    0.75596   -0.22839    0.69187
# 158   0.12586   -0.06178    0.23341  ...   -0.10297    0.08467    0.01373
# 4     0.77152   -0.16399    0.52798  ...   -0.65158    0.13290   -0.53206
# 0     1.00000    0.03760    0.85243  ...   -0.51171    0.41078   -0.46168
#
#      feature29  feature30  feature31  feature32  feature33  feature34  label
# 103    0.81428   -0.23728    0.89095   -0.31857    0.69531   -0.41573      g
# 262   -0.31713    0.60948   -0.40291    0.54522   -0.42815    0.44534      g
# 158    0.11213   -0.06636    0.09611   -0.07323    0.11670   -0.06865      b
# 4      0.02431   -0.62197   -0.05707   -0.59573   -0.04608   -0.65697      g
# 0      0.21266   -0.34090    0.42267   -0.54487    0.18641   -0.45300      g
#
# [5 rows x 34 columns]

# %%
data_set['label']=data_set['label'].map({'g':1,"b":0})

# %%
data_set.head()
# Out:
#      feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 103         1   0.95704  -0.12095   0.63318  -0.12690   0.96365  -0.18242
# 262         1   1.00000   0.09802   1.00000   0.25101   0.98390   0.33044
# 158         1   0.08696   0.00686   0.13959  -0.04119   0.10526  -0.08238
# 4           1   1.00000  -0.02401   0.94140   0.06531   0.92106  -0.23255
# 0           1   0.99539  -0.05889   0.85243   0.02306   0.83398  -0.37708
#
#      feature9  feature10  feature11  ...  feature26  feature27  feature28  \
# 103   0.97026    0.08460    0.92003  ...   -0.19233    0.88793   -0.31565
# 262   0.80365    0.53020    0.74977  ...    0.75596   -0.22839    0.69187
# 158   0.12586   -0.06178    0.23341  ...   -0.10297    0.08467    0.01373
# 4     0.77152   -0.16399    0.52798  ...   -0.65158    0.13290   -0.53206
# 0     1.00000    0.03760    0.85243  ...   -0.51171    0.41078   -0.46168
#
#      feature29  feature30  feature31  feature32  feature33  feature34  label
# 103    0.81428   -0.23728    0.89095   -0.31857    0.69531   -0.41573      1
# 262   -0.31713    0.60948   -0.40291    0.54522   -0.42815    0.44534      1
# 158    0.11213   -0.06636    0.09611   -0.07323    0.11670   -0.06865      0
# 4      0.02431   -0.62197   -0.05707   -0.59573   -0.04608   -0.65697      1
# 0      0.21266   -0.34090    0.42267   -0.54487    0.18641   -0.45300      1
#
# [5 rows x 34 columns]

# %%
data=data_set.iloc[:,:33]
labels=data_set.iloc[:,33:]

# %%
data.head()
# Out:
#      feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 103         1   0.95704  -0.12095   0.63318  -0.12690   0.96365  -0.18242
# 262         1   1.00000   0.09802   1.00000   0.25101   0.98390   0.33044
# 158         1   0.08696   0.00686   0.13959  -0.04119   0.10526  -0.08238
# 4           1   1.00000  -0.02401   0.94140   0.06531   0.92106  -0.23255
# 0           1   0.99539  -0.05889   0.85243   0.02306   0.83398  -0.37708
#
#      feature9  feature10  feature11  ...  feature25  feature26  feature27  \
# 103   0.97026    0.08460    0.92003  ...    1.00000   -0.19233    0.88793
# 262   0.80365    0.53020    0.74977  ...   -0.15144    0.75596   -0.22839
# 158   0.12586   -0.06178    0.23341  ...    0.15103   -0.10297    0.08467
# 4     0.77152   -0.16399    0.52798  ...    0.03286   -0.65158    0.13290
# 0     1.00000    0.03760    0.85243  ...    0.56811   -0.51171    0.41078
#
#      feature28  feature29  feature30  feature31  feature32  feature33  \
# 103   -0.31565    0.81428   -0.23728    0.89095   -0.31857    0.69531
# 262    0.69187   -0.31713    0.60948   -0.40291    0.54522   -0.42815
# 158    0.01373    0.11213   -0.06636    0.09611   -0.07323    0.11670
# 4     -0.53206    0.02431   -0.62197   -0.05707   -0.59573   -0.04608
# 0     -0.46168    0.21266   -0.34090    0.42267   -0.54487    0.18641
#
#      feature34
# 103   -0.41573
# 262    0.44534
# 158   -0.06865
# 4     -0.65697
# 0     -0.45300
#
# [5 rows x 33 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data,labels, test_size=0.40, random_state=40)

# %%
x_train.shape
# Out:
# (210, 33)

# %%
x_test.shape
# Out:
# (141, 33)

# %%
y_train.shape
# Out:
# (210, 1)

# %%
y_test.shape
# Out:
# (141, 1)

# %%
mean=x_train.mean()
std=x_train.std()
x_train -= mean
x_train /=std
x_test -= mean
x_test /=std

# %%
x_test.head()
# Out:
#      feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 100  0.332539  0.706178 -2.501685 -1.197122 -0.335938  0.409647 -2.363533
# 232 -2.992849  0.706178  2.312690 -3.148631 -2.702745 -3.265404 -2.378950
# 228 -2.992849  0.706178 -2.501685  0.754388  2.030869  0.865236  1.816342
# 115  0.332539 -0.789147 -0.323758 -0.546625 -0.166877 -0.806682  0.118256
# 234  0.332539  0.111044  2.312690  0.597740 -2.136771  0.488790 -0.190098
#
#      feature9  feature10  feature11  ...  feature25  feature26  feature27  \
# 100  0.568630   0.771944  -1.604948  ...  -2.491278  -1.946392  -2.874603
# 232 -1.032742  -0.400909  -0.857916  ...  -0.713556   0.113230   0.882094
# 228  0.947145   1.725865   0.924467  ...   1.064165  -1.946392   0.882094
# 115 -0.561331  -0.198355  -0.136479  ...  -0.078661   0.015151  -0.580971
# 234  0.473694  -0.173301   0.688996  ...   1.064165  -0.995794   0.680397
#
#      feature28  feature29  feature30  feature31  feature32  feature33  \
# 100  -1.717504   1.079988  -1.968214   1.150831  -2.106757  -0.720753
# 232  -1.717504  -0.622019   0.074232  -2.444594  -2.106757  -2.645382
# 228   2.030451   1.079988  -1.968214   1.150831   2.066325   1.203876
# 115   0.113559  -0.297820   0.074232  -0.341324  -0.062656  -0.437948
# 234   0.572796   0.587598   1.174008   1.150831  -0.156300   0.367086
#
#      feature34
# 100  -0.015349
# 232  -2.305484
# 228   2.274785
# 115  -0.058335
# 234   0.532291
#
# [5 rows x 33 columns]

# %%
x_train.head(3)
# Out:
#      feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 337  0.332539  0.518661  0.911370  0.054401  1.456327 -0.571401  1.714564
# 207  0.332539 -0.295488 -0.347878  0.437873 -0.294377  0.517332 -0.226451
# 217  0.332539  0.566430  0.005978  0.544913  0.037213  0.578115  0.133841
#
#      feature9  feature10  feature11  ...  feature25  feature26  feature27  \
# 337 -1.437609   1.652151  -1.846836  ...   0.077227  -1.578832   0.395695
# 207  0.321916  -0.512841   0.361608  ...   0.034953   0.546842   0.232542
# 217  0.623928   0.375917   0.579023  ...  -0.120864   1.251665  -0.489514
#
#      feature28  feature29  feature30  feature31  feature32  feature33  \
# 337  -0.878543   0.899831  -0.308216   0.933182   0.404583   0.637169
# 207   0.324532   0.273782  -0.355764   0.434442   0.178715   0.384330
# 217   1.172432  -0.242352   1.165879  -0.389593   1.004777  -0.498016
#
#      feature34
# 337   1.240835
# 207   0.207229
# 217   1.051189
#
# [3 rows x 33 columns]

# %%
x_test.head(3)
# Out:
#      feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 100  0.332539  0.706178 -2.501685 -1.197122 -0.335938  0.409647 -2.363533
# 232 -2.992849  0.706178  2.312690 -3.148631 -2.702745 -3.265404 -2.378950
# 228 -2.992849  0.706178 -2.501685  0.754388  2.030869  0.865236  1.816342
#
#      feature9  feature10  feature11  ...  feature25  feature26  feature27  \
# 100  0.568630   0.771944  -1.604948  ...  -2.491278  -1.946392  -2.874603
# 232 -1.032742  -0.400909  -0.857916  ...  -0.713556   0.113230   0.882094
# 228  0.947145   1.725865   0.924467  ...   1.064165  -1.946392   0.882094
#
#      feature28  feature29  feature30  feature31  feature32  feature33  \
# 100  -1.717504   1.079988  -1.968214   1.150831  -2.106757  -0.720753
# 232  -1.717504  -0.622019   0.074232  -2.444594  -2.106757  -2.645382
# 228   2.030451   1.079988  -1.968214   1.150831   2.066325   1.203876
#
#      feature34
# 100  -0.015349
# 232  -2.305484
# 228   2.274785
#
# [3 rows x 33 columns]

# %%
train=x_train

# %%
test=x_test

# %%
train.head()
# Out:
#      feature1  feature3  feature4  feature5  feature6  feature7  feature8  \
# 337  0.332539  0.518661  0.911370  0.054401  1.456327 -0.571401  1.714564
# 207  0.332539 -0.295488 -0.347878  0.437873 -0.294377  0.517332 -0.226451
# 217  0.332539  0.566430  0.005978  0.544913  0.037213  0.578115  0.133841
# 350  0.332539  0.415187  0.231267  0.239931 -0.481520  0.614774 -0.108039
# 198  0.332539 -0.495167 -2.501685 -3.148631 -2.702745 -1.358309  1.816342
#
#      feature9  feature10  feature11  ...  feature25  feature26  feature27  \
# 337 -1.437609   1.652151  -1.846836  ...   0.077227  -1.578832   0.395695
# 207  0.321916  -0.512841   0.361608  ...   0.034953   0.546842   0.232542
# 217  0.623928   0.375917   0.579023  ...  -0.120864   1.251665  -0.489514
# 350  0.727932  -0.595274   0.545443  ...   0.823586  -0.198061   0.527969
# 198  0.947145   1.620399   0.471688  ...  -0.659852   0.249968  -0.931583
#
#      feature28  feature29  feature30  feature31  feature32  feature33  \
# 337  -0.878543   0.899831  -0.308216   0.933182   0.404583   0.637169
# 207   0.324532   0.273782  -0.355764   0.434442   0.178715   0.384330
# 217   1.172432  -0.242352   1.165879  -0.389593   1.004777  -0.498016
# 350   0.066110   0.709070   0.059874   0.714832  -0.159555   0.929886
# 198   0.134248  -0.628878   0.040083  -0.660562  -0.017962  -0.720464
#
#      feature34
# 337   1.240835
# 207   0.207229
# 217   1.051189
# 350  -0.156216
# 198  -0.007906
#
# [5 rows x 33 columns]

# %%
train_label=np.asarray(y_train)
test_label=np.asarray(y_test)

# %%
# now we have the following
#train
#test
#train_label
#test_label

# %%
train.shape
# Out:
# (210, 33)

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

mymodel=models.Sequential()
mymodel.add(layers.Dense(16, activation='relu', input_shape=(train.shape[1],)))
mymodel.add(layers.Dense(12, activation='relu'))
mymodel.add(layers.Dense(1, activation='sigmoid'))

# %%
mymodel.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=['accuracy'])

# %%
mymodel.fit(train,train_label, epochs=100,batch_size=1)
# Out:
# Epoch 1/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.5212 - accuracy: 0.8095
# Epoch 2/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.3483 - accuracy: 0.8857
# Epoch 3/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.2986 - accuracy: 0.8905
# Epoch 4/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.2764 - accuracy: 0.9095
# Epoch 5/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.2531 - accuracy: 0.9095
# Epoch 6/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.2310 - accuracy: 0.9143
# Epoch 7/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.2303 - accuracy: 0.9190
# Epoch 8/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.2159 - accuracy: 0.9190
# Epoch 9/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.1918 - accuracy: 0.9143: 0s - loss: 0.3144
# Epoch 10/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.1851 - accuracy: 0.9333
# Epoch 11/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.1724 - accuracy: 0.9381
# Epoch 12/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.1585 - accuracy: 0.9381
# Epoch 13/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.1570 - accuracy: 0.9429
# Epoch 14/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.1422 - accuracy: 0.9429
# Epoch 15/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.1313 - accuracy: 0.9476
# Epoch 16/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.1235 - accuracy: 0.9524
# Epoch 17/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.1187 - accuracy: 0.9571
# Epoch 18/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.1046 - accuracy: 0.9714
# Epoch 19/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0959 - accuracy: 0.9619
# Epoch 20/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0941 - accuracy: 0.9619
# Epoch 21/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0839 - accuracy: 0.9762
# Epoch 22/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0883 - accuracy: 0.9762
# Epoch 23/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0789 - accuracy: 0.9810
# Epoch 24/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9810
# Epoch 25/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0753 - accuracy: 0.9810
# Epoch 26/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 0.9810
# Epoch 27/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0736 - accuracy: 0.9810
# Epoch 28/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0580 - accuracy: 0.9810
# Epoch 29/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0716 - accuracy: 0.9810
# Epoch 30/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0630 - accuracy: 0.9810
# Epoch 31/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0551 - accuracy: 0.9810
# Epoch 32/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.0664 - accuracy: 0.9810
# Epoch 33/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.0569 - accuracy: 0.9810
# Epoch 34/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.0607 - accuracy: 0.9857
# Epoch 35/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.0581 - accuracy: 0.9857
# Epoch 36/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0636 - accuracy: 0.9810
# Epoch 37/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0567 - accuracy: 0.9857
# Epoch 38/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0524 - accuracy: 0.9857
# Epoch 39/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0509 - accuracy: 0.9857
# Epoch 40/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 0.9857
# Epoch 41/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0499 - accuracy: 0.9857
# Epoch 42/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.0518 - accuracy: 0.9857
# Epoch 43/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.0485 - accuracy: 0.9857
# Epoch 44/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.0537 - accuracy: 0.9857
# Epoch 45/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0439 - accuracy: 0.9857
# Epoch 46/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.0473 - accuracy: 0.9857
# Epoch 47/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9857
# Epoch 48/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 0.9857
# Epoch 49/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9857
# Epoch 50/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0411 - accuracy: 0.9857
# Epoch 51/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0452 - accuracy: 0.9857
# Epoch 52/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 0.9905
# Epoch 53/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0503 - accuracy: 0.9857
# Epoch 54/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 0.9857
# Epoch 55/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 0.9905
# Epoch 56/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 0.9857
# Epoch 57/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 0.9905
# Epoch 58/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0454 - accuracy: 0.9905
# Epoch 59/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0353 - accuracy: 0.9905
# Epoch 60/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 0.9905
# Epoch 61/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0391 - accuracy: 0.9905
# Epoch 62/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 0.9905
# Epoch 63/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9952
# Epoch 64/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 0.9905
# Epoch 65/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0405 - accuracy: 0.9905
# Epoch 66/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0347 - accuracy: 0.9905
# Epoch 67/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0375 - accuracy: 0.9905
# Epoch 68/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0344 - accuracy: 0.9952
# Epoch 69/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0371 - accuracy: 0.9905
# Epoch 70/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0325 - accuracy: 0.9952
# Epoch 71/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0374 - accuracy: 0.9952
# Epoch 72/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0385 - accuracy: 0.9952
# Epoch 73/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0376 - accuracy: 0.9905
# Epoch 74/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.0351 - accuracy: 0.9952
# Epoch 75/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9905
# Epoch 76/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0327 - accuracy: 0.9952
# Epoch 77/100
# 210/210 [==============================] - 1s 2ms/step - loss: 0.0349 - accuracy: 0.9952
# Epoch 78/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0343 - accuracy: 0.9952
# Epoch 79/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9952
# Epoch 80/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0347 - accuracy: 0.9952
# Epoch 81/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 0.9952
# Epoch 82/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 0.9952
# Epoch 83/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9952
# Epoch 84/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0354 - accuracy: 0.9952
# Epoch 85/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 0.9952
# Epoch 86/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 0.9952
# Epoch 87/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 0.9952
# Epoch 88/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9952
# Epoch 89/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 0.9952
# Epoch 90/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0322 - accuracy: 0.9952 ETA: 0s - loss: 0.1070 - accuracy
# Epoch 91/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0377 - accuracy: 0.9952
# Epoch 92/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 0.9952
# Epoch 93/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9952
# Epoch 94/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0385 - accuracy: 0.9952
# Epoch 95/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9952
# Epoch 96/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0402 - accuracy: 0.9952
# Epoch 97/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9952
# Epoch 98/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9952
# Epoch 99/100
# 210/210 [==============================] - 1s 3ms/step - loss: 0.0396 - accuracy: 0.9952
# Epoch 100/100
# 210/210 [==============================] - 0s 2ms/step - loss: 0.0365 - accuracy: 0.9952

# %%
results = mymodel.evaluate(test, test_label)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8499 - accuracy: 0.8723

# %%
pred=mymodel.predict(test)
pred[0:10]
# Out:
# array([[2.2208691e-04],
#        [0.0000000e+00],
#        [1.4742911e-03],
#        [2.6367569e-01],
#        [9.9999928e-01],
#        [9.9978757e-01],
#        [9.7325313e-01],
#        [1.0000000e+00],
#        [9.9324226e-01],
#        [1.7124924e-07]], dtype=float32)

# %%
train_label[0:10]
# Out:
# array([[1],
#        [1],
#        [1],
#        [1],
#        [0],
#        [1],
#        [1],
#        [1],
#        [1],
#        [1]], dtype=int64)

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

mymodel=models.Sequential()
mymodel.add(layers.Dense(16,kernel_regularizer=regularizers.l2(0.001),
                         activation='relu', input_shape=(train.shape[1],)))
mymodel.add(layers.Dense(12,kernel_regularizer=regularizers.l2(0.001),
                         activation='relu'))
mymodel.add(layers.Dense(1, activation='sigmoid'))

# %%
mymodel.compile(optimizer='rmsprop',
               loss='binary_crossentropy',
               metrics=['accuracy'])

# %%
mymodel.fit(train,train_label, epochs=100,batch_size=1, verbose=0)

# %%
results = mymodel.evaluate(test, test_label)
results
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.9867 - accuracy: 0.8511
# [0.9867478013038635, 0.8510638475418091]

# %%
pred=mymodel.predict(test)
pred[0:10]
# Out:
# array([[9.0569437e-02],
#        [1.4010187e-16],
#        [8.1052661e-02],
#        [9.2424309e-01],
#        [9.9939287e-01],
#        [9.9989760e-01],
#        [8.9427823e-01],
#        [9.9997139e-01],
#        [9.8778546e-01],
#        [2.2546887e-02]], dtype=float32)

# %%
train_label[0:10]
# Out:
# array([[1],
#        [1],
#        [1],
#        [1],
#        [0],
#        [1],
#        [1],
#        [1],
#        [1],
#        [1]], dtype=int64)
